# %%
pwd
# cd ..
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-443641216559> in <module>()
# ----> 1 pwd
#       2 # cd ..
#
# NameError: name 'pwd' is not defined

# %%
import pandas as pd

# %%
# log_df = pd.read_csv("data/interim/mdl_logstore_standard_log_100000.csv")
# badge_df = pd.read_csv("data/raw/mdl_badge_issued.csv")
# course_modules_df = pd.read_csv("data/raw/mdl_course_modules.csv")
# completion_df = pd.read_csv("data/raw/mdl_course_modules_completion.csv")
# grades_history_df = pd.read_csv("data/raw/mdl_grade_grades_history.csv")
# user_df = pd.read_csv("data/raw/mdl_user.csv")

# %% [markdown]
# ### Users

# %%
user_df = pd.read_csv("data/raw/mdl_user.csv")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-2275266918ab> in <module>()
# ----> 1 user_df = pd.read_csv("data/raw/mdl_user.csv")
#
# ...

# %%
user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2170 entries, 0 to 2169
# Data columns (total 48 columns):
# id                   2170 non-null int64
# confirmed            2170 non-null int64
# deleted              2170 non-null int64
# suspended            2170 non-null int64
# mnethostid           2170 non-null int64
# username             2170 non-null object
# idnumber             0 non-null float64
# firstname            2170 non-null object
# lastname             2170 non-null object
# email                2170 non-null object
# emailstop            2170 non-null int64
# icq                  1 non-null object
# skype                26 non-null object
# yahoo                5 non-null object
# aim                  0 non-null float64
# msn                  2 non-null object
# phone1               19 non-null object
# phone2               23 non-null object
# institution          49 non-null object
# department           36 non-null object
# ...

# %%
user_df.head()
# Out:
#    id  confirmed  deleted  suspended  mnethostid                 username  \
# 0   0          1        0          0           1   user186977097674129409
# 1   0          1        0          0           1  user4786049973974204417
# 2   0          1        0          0           1  user7133053338412646401
# 3   0          1        0          0           1  user3543713697010548737
# 4   0          1        0          0           1  user1626801571545219073
#
#    idnumber                       firstname                     lastname  \
# 0       NaN   WjLE Pjb a VUQhOz yem tGdQmvn   r  nrmZZflGFBbefW REfdbNtc
# 1       NaN  gDOm SYE kqhByCiKt UKeBhg dhsS  rYPW  nh uwBnv mRBNDSqXARSS
# 2       NaN  drbW XEKAWJ Uuf xI SHCBFLbQB H  bk HPF g bJfbmkXA ELjDgTfXK
# 3       NaN  j jFL wXXlycRoDTOOFkDATM Wn xY   ntXGuKKFnZM DDzIKJ SGcDDAQ
# 4       NaN  ELnLGLosOo ZpbuQ p Rltre o  EX  BWH tPHVEGvLM FR WAOcwKuJfC
#
#                              email     ...       autosubscribe trackforums  \
# ...

# %%
user_df.columns
# Out:
# Index([u'id', u'confirmed', u'deleted', u'suspended', u'mnethostid',
#        u'username', u'idnumber', u'firstname', u'lastname', u'email',
#        u'emailstop', u'icq', u'skype', u'yahoo', u'aim', u'msn', u'phone1',
#        u'phone2', u'institution', u'department', u'address', u'city',
#        u'country', u'lang', u'theme', u'timezone', u'firstaccess',
#        u'lastaccess', u'lastlogin', u'currentlogin', u'lastip', u'picture',
#        u'url', u'description', u'descriptionformat', u'mailformat',
#        u'maildigest', u'maildisplay', u'autosubscribe', u'trackforums',
#        u'timecreated', u'timemodified', u'trustbitmask', u'lastnamephonetic',
#        u'firstnamephonetic', u'middlename', u'alternatename', u'calendartype'],
#       dtype='object')

# %% [markdown]
# Show what columns have all the same values and should be dropped:

# %%
for c in user_df.columns:
    if len(user_df[c].unique()) == 1:
        print c, user_df[c][0]
# Out:
# id 0
# confirmed 1
# deleted 0
# suspended 0
# mnethostid 1
# idnumber nan
# emailstop 0
# aim nan
# picture 0
# descriptionformat 1
# trustbitmask 0
# calendartype gregorian

# %%
users = user_df.drop([c for c in user_df.columns if len(user_df[c].unique()) == 1], axis=1)

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2170 entries, 0 to 2169
# Data columns (total 36 columns):
# username             2170 non-null object
# firstname            2170 non-null object
# lastname             2170 non-null object
# email                2170 non-null object
# icq                  1 non-null object
# skype                26 non-null object
# yahoo                5 non-null object
# msn                  2 non-null object
# phone1               19 non-null object
# phone2               23 non-null object
# institution          49 non-null object
# department           36 non-null object
# address              21 non-null object
# city                 1861 non-null object
# country              2063 non-null object
# lang                 2170 non-null object
# theme                4 non-null object
# timezone             2170 non-null object
# firstaccess          2170 non-null int64
# lastaccess           2170 non-null int64
# ...

# %%
users.country.unique()
# Out:
# array(['AU', nan], dtype=object)

# %%
users.country.isnull().sum()
# Out:
# 107

# %%
users.city.isnull().sum()
# Out:
# 309

# %%
len(users.city.unique())
# Out:
# 1860

# %%
users.lang.unique()
# Out:
# array(['en_us', 'es', 'en', 'bg', 'it', 'es_mx', 'fr', 'uk', 'ja', 'ru',
#        'nl', 'vi', 'pt_br', 'ko', 'de', 'zh_tw', 'pt', 'he', 'lt', 'pl',
#        'da', 'no', 'el', 'hr', 'sv', 'ca', 'zh_cn', 'sl', 'ar', 'es_ve',
#        'hu', 'sr', 'sr_lt', 'sk', 'hi', 'tr', 'fr_ca', 'is', 'ro', 'id',
#        'th', 'ur'], dtype=object)

# %% [markdown]
# ### Badges

# %%
badge_df = pd.read_csv("data/raw/mdl_badge_issued.csv")

# %%
badge_df.head()
# Out:
#                   username                                uniquehash  \
# 0  user6442803380426375169  dff34e86c5ac6c8ec7650673998a2c5f66a33e53
# 1  user6442803380426375169  dff34e86c5ac6c8ec7650673998a2c5f66a33e53
# 2  user8540069828419911681  a4f714807acfdb2c8a6367f095ee9179b590e333
# 3  user8540069828419911681  a4f714807acfdb2c8a6367f095ee9179b590e333
# 4  user2882394166283730945  c9a55d27a003befb7f7da54d2f919435b05504d1
#
#    dateissued  visible
# 0  1470554624        1
# 1  1470554624        1
# 2  1470554624        1
# 3  1470554624        1
# 4  1470554624        1

# %%
badge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1844 entries, 0 to 1843
# Data columns (total 4 columns):
# username      1844 non-null object
# uniquehash    1844 non-null object
# dateissued    1844 non-null int64
# visible       1844 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 57.7+ KB

# %%
badge_df.groupby('username').count().uniquehash.max()
# Out:
# 3

# %%
len(badge_df.uniquehash.unique())
# Out:
# 1842

# %% [markdown]
# ## Log

# %%
log_df = pd.read_csv("../data/interim/mdl_logstore_standard_log_100000.csv")
# Out:
# /Users/kdmytro/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
log_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99932 entries, 0 to 99931
# Data columns (total 21 columns):
# username             99932 non-null object
# id                   99932 non-null int64
# eventname            99932 non-null object
# component            99932 non-null object
# action               99932 non-null object
# target               99932 non-null object
# objecttable          35712 non-null object
# objectid             35712 non-null float64
# crud                 99932 non-null object
# edulevel             99932 non-null int64
# contextid            99932 non-null int64
# contextlevel         99932 non-null int64
# contextinstanceid    99932 non-null int64
# courseid             99932 non-null int64
# anonymous            99932 non-null int64
# other                99932 non-null object
# timecreated          99932 non-null int64
# origin               99932 non-null object
# ip                   99932 non-null object
# ...

# %%
log_df[log_df.columns[20]]
log_df.columns[20]
# Out:
# 'realusername'

# %%
log_df.head(3).T
# Out:
#                                            0                          1  \
# username             user8540069828419911681    user8540069828419911681
# id                                     25017                      25017
# eventname          \core\event\course_viewed  \core\event\course_viewed
# component                               core                       core
# action                                viewed                     viewed
# target                                course                     course
# objecttable                              NaN                        NaN
# objectid                                 NaN                        NaN
# crud                                       r                          r
# edulevel                                   2                          2
# contextid                             107483                     107483
# contextlevel                              50                         50
# ...

# %%
# Create, Read, Update, Delete
log_df.crud.unique()
# Out:
# array(['r', 'c', 'u', 'd'], dtype=object)

# %%
sorted(log_df.eventname.unique())
# Out:
# ['\\booktool_exportimscp\\event\\book_exported',
#  '\\booktool_print\\event\\book_printed',
#  '\\core\\event\\blog_comment_created',
#  '\\core\\event\\blog_entries_viewed',
#  '\\core\\event\\blog_entry_created',
#  '\\core\\event\\blog_entry_deleted',
#  '\\core\\event\\calendar_event_created',
#  '\\core\\event\\calendar_event_deleted',
#  '\\core\\event\\calendar_event_updated',
#  '\\core\\event\\course_category_created',
#  '\\core\\event\\course_content_deleted',
#  '\\core\\event\\course_deleted',
#  '\\core\\event\\course_module_completion_updated',
#  '\\core\\event\\course_module_created',
#  '\\core\\event\\course_module_deleted',
#  '\\core\\event\\course_module_updated',
#  '\\core\\event\\course_restored',
#  '\\core\\event\\course_section_updated',
#  '\\core\\event\\course_updated',
#  '\\core\\event\\course_viewed',
#  '\\core\\event\\message_contact_added',
#  '\\core\\event\\message_contact_removed',
#  '\\core\\event\\message_sent',
# ...

# %%
log_counts = log_df.groupby('eventname', sort=False).count()['id'].sort_values(ascending=False)
log_counts
# Out:
# eventname
# \core\event\message_sent                                   50115
# \core\event\course_viewed                                   9358
# \mod_forum\event\discussion_viewed                          9096
# \core\event\message_viewed                                  7778
# \mod_forum\event\course_module_viewed                       5497
# \core\event\webservice_function_called                      3975
# \mod_forum\event\assessable_uploaded                        1625
# \core\event\user_profile_viewed                             1316
# \mod_book\event\chapter_viewed                              1270
# \mod_forum\event\post_created                               1252
# \core\event\user_loggedin                                    961
# \core\event\user_list_viewed                                 826
# \mod_page\event\course_module_viewed                         771
# \mod_wiki\event\page_viewed                                  452
# ...

# %%
import numpy as np
rare_events = log_counts[log_counts < 3].index
log_df.where('eventname' in rare_events)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-a5a5381db71a> in <module>()
#       1 import numpy as np
#       2 rare_events = log_counts[log_counts < 3].index
# ----> 3 log_df.where('eventname' in rare_events)
#
# /Users/kdmytro/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in where(self, cond, other, inplace, axis, level, try_cast, raise_on_error)
#    4811         other = com._apply_if_callable(other, self)
#    4812         return self._where(cond, other, inplace, axis, level, try_cast,
# -> 4813                            raise_on_error)
#    4814
#    4815     @Appender(_shared_docs['where'] % dict(_shared_doc_kwargs, cond="False",
#
# /Users/kdmytro/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _where(self, cond, other, inplace, axis, level, try_cast, raise_on_error)
#    4558         else:
# ...

# %%
course_modules_df = pd.read_csv("../data/raw/mdl_course_modules.csv")

# %%
course_modules_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 21 columns):
# name                         60 non-null object
# id                           60 non-null int64
# course                       60 non-null int64
# module                       60 non-null int64
# instance                     60 non-null int64
# section                      60 non-null int64
# idnumber                     0 non-null float64
# added                        60 non-null int64
# score                        60 non-null int64
# indent                       60 non-null int64
# visible                      60 non-null int64
# visibleold                   60 non-null int64
# groupmode                    60 non-null int64
# groupingid                   60 non-null int64
# completion                   60 non-null int64
# completiongradeitemnumber    4 non-null float64
# completionview               60 non-null int64
# completionexpected           60 non-null int64
# ...

# %%
course_modules_df.head(3).T
# Out:
#                                     0           1           2
# name                            forum      survey    feedback
# id                              54984       55004       54995
# course                          10464       10464       10464
# module                              9          19           7
# instance                        13387         662        1007
# section                         58964       58966       58965
# idnumber                          NaN         NaN         NaN
# added                      1372670270  1378189004  1372678410
# score                               0           0           0
# indent                              0           0           0
# visible                             1           1           1
# visibleold                          1           1           1
# groupmode                           0           0           0
# groupingid                          0           0           0
# ...

# %%
course_modules_df[course_modules_df.section == 58964]
# Out:
#      name     id  course  module  instance  section  idnumber       added  \
# 0   forum  54984   10464       9     13387    58964       NaN  1372670270
# 12   page  54985   10464      15      4211    58964       NaN  1377683443
# 47   page  55043   10464      15      4226    58964       NaN  1457605162
# 52  label  55329   10464      12      5478    58964       NaN  1470636237
# 54  label  54987   10464      12      5447    58964       NaN  1420804201
# 56   page  54986   10464      15      4212    58964       NaN  1377683443
#
#     score  indent        ...          visibleold  groupmode  groupingid  \
# 0       0       0        ...                   1          0           0
# 12      0       0        ...                   1          0           0
# 47      0       0        ...                   1          0           0
# 52      0       0        ...                   1          0           0
# 54      0       0        ...                   1          0           0
# ...

# %%
grades_history_df = pd.read_csv("../data/raw/mdl_grade_grades_history.csv")

# %%
grades_history_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70037 entries, 0 to 70036
# Data columns (total 24 columns):
# username             70037 non-null object
# id                   70037 non-null int64
# action               70037 non-null int64
# oldid                70037 non-null int64
# source               34311 non-null object
# timemodified         70037 non-null int64
# itemid               70037 non-null int64
# rawgrade             8720 non-null float64
# rawgrademax          70037 non-null float64
# rawgrademin          70037 non-null float64
# rawscaleid           943 non-null float64
# usermodified         8755 non-null float64
# finalgrade           22054 non-null float64
# hidden               70037 non-null int64
# locked               70037 non-null int64
# locktime             70037 non-null int64
# exported             70037 non-null int64
# overridden           70037 non-null int64
# excluded             70037 non-null int64
# ...

# %%
grades_history_df[~grades_history_df.feedback.isnull()]
# Out:
#                       username      id  action   oldid      source  \
# 962    user8023781421904560129  284988       2  112285         NaN
# 963    user8023781421904560129  270840       2  112285         NaN
# 968    user8023781421904560129  247358       2  112285  mod/assign
# 1975   user1665969594520567809  301749       2  112780  mod/assign
# 3750   user1538973497546506241  302554       2  119053  mod/assign
# 4443   user1406505393194008577  299047       2  111833  mod/assign
# 6888   user2000452477777870849  304635       2  128248  mod/assign
# 17943  user5350080554052091905  302560       2  131082  mod/assign
# 18203  user4791183426260566017  302559       2  119113  mod/assign
# 23450  user7542936550099648513  311671       2  125689  mod/assign
# 25740  user7672648505218826241  299048       2  118554  mod/assign
# 26099  user1283475891791331329  300085       2  114525  mod/assign
# 26783  user6890768104326955009  301142       2  111063  mod/assign
# ...
